# %% [markdown]
# # Movie Recommendation System - Analysis
#
# This notebook explores the TMDB 5000 dataset and validates the ML pipeline.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

DATA_DIR = '../data'
movies = pd.read_csv(f'{DATA_DIR}/tmdb_5000_movies.csv')
credits = pd.read_csv(f'{DATA_DIR}/tmdb_5000_credits.csv')

print(f"Movies shape: {movies.shape}")
print(f"Credits shape: {credits.shape}")

# %% [markdown]
# ## 1. Data Merging

# %%
df = movies.merge(credits, on='title')
df.head()
